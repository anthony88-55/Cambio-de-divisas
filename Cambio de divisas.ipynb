# %%
from datetime import datetime, time

# %%
nombre = "Anthony"
fecha = datetime.now().date()
hora = datetime.now().time()
rango_hora_noche = [time(hour= 17, minute=0, second =0), time(hour= 23, minute=59, second =59) ]
rango_hora_tarde = [time(hour= 12, minute=0, second =0), time(hour= 16, minute=59, second =59) ]
momento_dia = ""

# %%
if (hora > rango_hora_noche[0]) and (hora < rango_hora_noche[1]):
    momento = "Buenas noches"

elif (hora > rango_hora_tarde[0]) and (hora < rango_hora_tarde[1]):

    momento = "Buenas tardes"
else:
    momento = "Buenos días"

dolares = 145.2543

# %%
bienvenida = f"{momento} {nombre}! Hoy es {fecha} {hora}"
bienvenida
# Out:
# 'Buenas noches Anthony! Hoy es 2026-01-05 21:03:18.118463'

# %%
euro = dolares * 0.88
euro
# Out:
# 127.823784

# %%
billetes_10 = euro // 10
billetes_10
# Out:
# 12.0

# %%
billetes_1 = (euro - (billetes_10 * 10)) // 1
billetes_1
# Out:
# 7.0

# %%
monedas = euro % 1
monedas
# Out:
# 0.8237840000000034

# %%
print(bienvenida)
print("")
print("Dolares a cambiar:")
print(dolares)
print("")
print("Total euros a recibir:")
print(euro)
print("")
print("Billetes:")
print("")
print("Billetes de 10: ", billetes_10)
print("Billete de 1: ", billetes_1)
print("Monedas: ", monedas)
print("")
# Out:
# Buenas noches Anthony! Hoy es 2026-01-05 21:03:18.118463
#
# Dolares a cambiar:
# 145.2543
#
# Total euros a recibir:
# 127.823784
#
# Billetes:
#
# Billetes de 10:  12.0
# Billete de 1:  7.0
# Monedas:  0.8237840000000034
